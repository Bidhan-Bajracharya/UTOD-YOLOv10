# %%
from ultralytics import YOLOv10

# %%
# import os
# from pathlib import Path

# # --- change this to your labels folder ---
# LABELS_DIR = r"D:\UTOD\TrashCan\material\labels\train"
# BACKUP_DIR = LABELS_DIR + "_backup"

# os.makedirs(BACKUP_DIR, exist_ok=True)

# def clamp01(v):
#     return max(0.0, min(1.0, v))

# bad_files, bad_lines, fixed_lines = 0, 0, 0

# for txt in Path(LABELS_DIR).rglob("*.txt"):
#     with open(txt, "r") as f:
#         lines = [ln.strip() for ln in f if ln.strip()]

#     new_lines = []
#     changed = False
#     for ln in lines:
#         parts = ln.split()
#         if len(parts) != 5:
#             changed = True
#             continue
#         cls, x, y, w, h = parts
#         try:
#             x, y, w, h = map(float, (x, y, w, h))
#         except:
#             changed = True
#             continue

#         if not (0 <= x <= 1 and 0 <= y <= 1 and 0 <= w <= 1 and 0 <= h <= 1):
#             bad_lines += 1
#             changed = True
#             x, y, w, h = [clamp01(v) for v in (x, y, w, h)]
#             fixed_lines += 1

#         new_lines.append(f"{cls} {x:.6f} {y:.6f} {w:.6f} {h:.6f}")

#     if changed:
#         # backup original file
#         backup_path = Path(BACKUP_DIR) / txt.name
#         if not backup_path.exists():
#             with open(backup_path, "w") as bf:
#                 bf.write("\n".join(lines))
#         # overwrite with fixed
#         with open(txt, "w") as wf:
#             wf.write("\n".join(new_lines))
#         bad_files += 1

# print("=== Scan & Fix Report ===")
# print(f"Files with issues : {bad_files}")
# print(f"Problem boxes     : {bad_lines}")
# print(f"Fixed boxes       : {fixed_lines}")
# print("✅ All labels now clamped to [0,1].")

# %%
# import os
# from pathlib import Path

# # --- change this to your labels folder ---
# LABELS_DIR = r"D:\UTOD\TrashCan\material\labels\val"
# BACKUP_DIR = LABELS_DIR + "_backup"

# os.makedirs(BACKUP_DIR, exist_ok=True)

# def clamp01(v):
#     return max(0.0, min(1.0, v))

# bad_files, bad_lines, fixed_lines = 0, 0, 0

# for txt in Path(LABELS_DIR).rglob("*.txt"):
#     with open(txt, "r") as f:
#         lines = [ln.strip() for ln in f if ln.strip()]

#     new_lines = []
#     changed = False
#     for ln in lines:
#         parts = ln.split()
#         if len(parts) != 5:
#             changed = True
#             continue
#         cls, x, y, w, h = parts
#         try:
#             x, y, w, h = map(float, (x, y, w, h))
#         except:
#             changed = True
#             continue

#         if not (0 <= x <= 1 and 0 <= y <= 1 and 0 <= w <= 1 and 0 <= h <= 1):
#             bad_lines += 1
#             changed = True
#             x, y, w, h = [clamp01(v) for v in (x, y, w, h)]
#             fixed_lines += 1

#         new_lines.append(f"{cls} {x:.6f} {y:.6f} {w:.6f} {h:.6f}")

#     if changed:
#         # backup original file
#         backup_path = Path(BACKUP_DIR) / txt.name
#         if not backup_path.exists():
#             with open(backup_path, "w") as bf:
#                 bf.write("\n".join(lines))
#         # overwrite with fixed
#         with open(txt, "w") as wf:
#             wf.write("\n".join(new_lines))
#         bad_files += 1

# print("=== Scan & Fix Report ===")
# print(f"Files with issues : {bad_files}")
# print(f"Problem boxes     : {bad_lines}")
# print(f"Fixed boxes       : {fixed_lines}")
# print("✅ All labels now clamped to [0,1].")

# %%
model = YOLOv10('yolov10n.yaml') # build a new model from YAML

# %%
# import yaml
# from pathlib import Path

# with open("data/trashcan.yaml") as f:
#     cfg = yaml.safe_load(f)

# print("Number of classes in names:", len(cfg["names"]))
# print("Max class id in dataset:", max(
#     int(line.split()[0])
#     for txt in Path("D:/UTOD/TrashCan/material/labels/train").rglob("*.txt")
#     for line in open(txt)
# ))

# Number of classes in names: 16
# Max class id in dataset: 15

# %%
SEED=42

# %%
model.train(
    data='data/trashcan.yaml',  # points to the file you made
    epochs=100,
    imgsz=640,
    batch=-1,
    device=0,
    pretrained=False,
    workers=0,
    seed=SEED
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.207 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.9.23 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# engine\trainer: task=detect, mode=train, model=yolov10n.yaml, data=data/trashcan.yaml, epochs=100, time=None, patience=100, batch=-1, imgsz=640, save=True, save_period=-1, val_period=1, cache=False, device=0, workers=0, project=None, name=train6, exist_ok=False, pretrained=False, optimizer=auto, verbose=True, seed=42, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=D:\UTOD\yolov10\runs\detect\train6
# Overriding model.yaml nc=80 with nc=16
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1      9856  ultralytics.nn.modules.block.SCDown          [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1     36096  ultralytics.nn.modules.block.SCDown          [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.PSA             [256, 256]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         3  ultralytics.nn.bifpn.BiFPN                   [1]
#  13                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         3  ultralytics.nn.bifpn.BiFPN                   [1]
#  16                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         3  ultralytics.nn.bifpn.BiFPN                   [1]
#  19                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  20                  -1  1     18048  ultralytics.nn.modules.block.SCDown          [128, 128, 3, 2]
#  21            [-1, 10]  1         3  ultralytics.nn.bifpn.BiFPN                   [1]
#  22                  -1  1    282624  ultralytics.nn.modules.block.C2fCIB          [384, 256, 1, True, True]
#  23        [16, 19, 22]  1    867568  ultralytics.nn.modules.head.v10Detect        [16, [64, 128, 256]]
# YOLOv10n summary: 385 layers, 2713292 parameters, 2713276 gradients, 8.4 GFLOPs
#
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# AutoBatch: Computing optimal batch size for imgsz=640
# AutoBatch: CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU) 8.00G total, 3.07G reserved, 0.19G allocated, 4.74G free
#       Params      GFLOPs  GPU_mem (GB)  forward (ms) backward (ms)                   input                  output
#      2713292       8.426         3.481         67.97           nan        (1, 3, 640, 640)                    list
#      2713292       16.85         0.835         70.19           nan        (2, 3, 640, 640)                    list
#      2713292       33.71         1.464         36.95           nan        (4, 3, 640, 640)                    list
#      2713292       67.41         2.777         32.36           nan        (8, 3, 640, 640)                    list
#      2713292       134.8         5.220          79.3           nan       (16, 3, 640, 640)                    list
# AutoBatch: Using batch-size 6 for CUDA:0 5.97G/8.00G (75%) ✅
# train: Scanning D:\UTOD\TrashCan\material\labels\train.cache... 6008 images, 0 backgrounds, 0 corrupt: 100%|██████████| 6008/6008 [00:00<?, ?it/s]
# val: Scanning D:\UTOD\TrashCan\material\labels\val.cache... 1204 images, 0 backgrounds, 0 corrupt: 100%|██████████| 1204/1204 [00:00<?, ?it/s]
# Plotting labels to D:\UTOD\yolov10\runs\detect\train6\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.0005, momentum=0.9) with parameter groups 95 weight(decay=0.0), 112 weight(decay=0.000515625), 107 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to D:\UTOD\yolov10\runs\detect\train6
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#       1/100      3.12G       3.57      5.346      4.111      3.336      10.45      4.203          9        640: 100%|██████████| 1002/1002 [06:31<00:00,  2.56it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 101/101 [00:43<00:00,  2.35it/s]
#                    all       1204       2594   0.000826     0.0866    0.00162   0.000488
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#       2/100       1.3G      3.044      4.798      3.414      2.719      6.998      3.341         29        640:  81%|████████  | 809/1002 [06:20<01:30,  2.13it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 model.train(
#       2     data='data/trashcan.yaml',  # points to the file you made
#       3     epochs=100,
#       4     imgsz=640,
#       5     batch=-1,
#       6     device=0,
#       7     pretrained=False,
#       8     workers=0,
#       9     seed=SEED
#      10 )
#
# File d:\UTOD\UTOD-YOLOv10\ultralytics\engine\model.py:657, in Model.train(self, trainer, **kwargs)
#     654             pass
#     656 self.trainer.hub_session = self.session  # attach optional HUB session
# --> 657 self.trainer.train()
#     658 # Update model and cfg after training
#     659 if RANK in (-1, 0):
#
# File d:\UTOD\UTOD-YOLOv10\ultralytics\engine\trainer.py:213, in BaseTrainer.train(self)
#     210         ddp_cleanup(self, str(file))
#     212 else:
# --> 213     self._do_train(world_size)
#
# File d:\UTOD\UTOD-YOLOv10\ultralytics\engine\trainer.py:363, in BaseTrainer._do_train(self, world_size)
#     361 self.tloss = None
#     362 self.optimizer.zero_grad()
# --> 363 for i, batch in pbar:
#     364     self.run_callbacks("on_train_batch_start")
#     365     # Warmup
#
# File c:\Users\Bidhan\anaconda3\envs\utod\lib\site-packages\tqdm\std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File d:\UTOD\UTOD-YOLOv10\ultralytics\data\build.py:49, in InfiniteDataLoader.__iter__(self)
#      47 """Creates a sampler that repeats indefinitely."""
#      48 for _ in range(len(self)):
# ---> 49     yield next(self.iterator)
#
# File c:\Users\Bidhan\anaconda3\envs\utod\lib\site-packages\torch\utils\data\dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# --> 631 data = self._next_data()
#     632 self._num_yielded += 1
#     633 if self._dataset_kind == _DatasetKind.Iterable and \
#     634         self._IterableDataset_len_called is not None and \
#     635         self._num_yielded > self._IterableDataset_len_called:
#
# File c:\Users\Bidhan\anaconda3\envs\utod\lib\site-packages\torch\utils\data\dataloader.py:675, in _SingleProcessDataLoaderIter._next_data(self)
#     673 def _next_data(self):
#     674     index = self._next_index()  # may raise StopIteration
# --> 675     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     676     if self._pin_memory:
#     677         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\Bidhan\anaconda3\envs\utod\lib\site-packages\torch\utils\data\_utils\fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File c:\Users\Bidhan\anaconda3\envs\utod\lib\site-packages\torch\utils\data\_utils\fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File d:\UTOD\UTOD-YOLOv10\ultralytics\data\base.py:253, in BaseDataset.__getitem__(self, index)
#     251 def __getitem__(self, index):
#     252     """Returns transformed label information for given index."""
# --> 253     return self.transforms(self.get_image_and_label(index))
#
# File d:\UTOD\UTOD-YOLOv10\ultralytics\data\augment.py:74, in Compose.__call__(self, data)
#      72 """Applies a series of transformations to input data."""
#      73 for t in self.transforms:
# ---> 74     data = t(data)
#      75 return data
#
# File d:\UTOD\UTOD-YOLOv10\ultralytics\data\augment.py:74, in Compose.__call__(self, data)
#      72 """Applies a series of transformations to input data."""
#      73 for t in self.transforms:
# ---> 74     data = t(data)
#      75 return data
#
# File d:\UTOD\UTOD-YOLOv10\ultralytics\data\augment.py:122, in BaseMixTransform.__call__(self, labels)
#     119 labels["mix_labels"] = mix_labels
#     121 # Mosaic or MixUp
# --> 122 labels = self._mix_transform(labels)
#     123 labels.pop("mix_labels", None)
#     124 return labels
#
# File d:\UTOD\UTOD-YOLOv10\ultralytics\data\augment.py:171, in Mosaic._mix_transform(self, labels)
#     168 assert labels.get("rect_shape", None) is None, "rect and mosaic are mutually exclusive."
#     169 assert len(labels.get("mix_labels", [])), "There are no other images for mosaic augment."
#     170 return (
# --> 171     self._mosaic3(labels) if self.n == 3 else self._mosaic4(labels) if self.n == 4 else self._mosaic9(labels)
#     172 )
#
# File d:\UTOD\UTOD-YOLOv10\ultralytics\data\augment.py:221, in Mosaic._mosaic4(self, labels)
#     219 # Place img in img4
#     220 if i == 0:  # top left
# --> 221     img4 = np.full((s * 2, s * 2, img.shape[2]), 114, dtype=np.uint8)  # base image with 4 tiles
#     222     x1a, y1a, x2a, y2a = max(xc - w, 0), max(yc - h, 0), xc, yc  # xmin, ymin, xmax, ymax (large image)
#     223     x1b, y1b, x2b, y2b = w - (x2a - x1a), h - (y2a - y1a), w, h  # xmin, ymin, xmax, ymax (small image)
#
# File c:\Users\Bidhan\anaconda3\envs\utod\lib\site-packages\numpy\core\numeric.py:330, in full(shape, fill_value, dtype, order, like)
#     328     dtype = fill_value.dtype
#     329 a = empty(shape, dtype, order)
# --> 330 multiarray.copyto(a, fill_value, casting='unsafe')
#     331 return a
#
# KeyboardInterrupt:
